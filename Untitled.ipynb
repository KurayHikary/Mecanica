# %%
import numpy as np  
import matplotlib.pyplot as plt

# %%
t=np.linspace(0,10,100)
w=10**(2.5)
vi=5*np.sin(w*t)
v=(((0.00001)*w**2)+1)*vi
plt.figure()
plt.plot(t,v, color='m')
plt.ylabel('some numbers')
plt.show()
